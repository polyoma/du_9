# %%
import pandas as pd

# %%
import numpy as np

# %%
link = 'https://www.czso.cz/documents/10180/32853391/300002164403.xlsx/1fed9fb2-4dbf-4b0f-bfbe-4c2d3202a18f?version=1.1'

# %%
pd.read_excel(link)
# Out:
#                                          PRÁCE A MZDY  \
# 0   4 - 3.  Mezinárodní srovnání - Ekonomicky neak...
# 1     International surveys - Economically inactiv...
# 2                                                 NaN
# 3               Pramen / Source: Eurostat, 05/12/2016
# 4                                                 NaN
# 5                                                Země
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                              EU 28
# 11                                        Eurozóna 19
# 12                                             v tom:
# 13                                             Belgie
# 14                                          Bulharsko
# 15                                    Česká republika
# ...

# %%
pd.read_excel(link, header = 5)
# Out:
#                         Země Studují či se jinak připravují na výkon povolání  \
# 0                        NaN                         In education or training
# 1                        NaN                              15 - 24 let / years
# 2                        NaN                                             ženy
# 3                        NaN                                            Women
# 4                      EU 28                                              NaN
# 5                Eurozóna 19                                              NaN
# 6                     v tom:                                              NaN
# 7                     Belgie                                              NaN
# 8                  Bulharsko                                              NaN
# 9            Česká republika                                              NaN
# 10                    Dánsko                                              NaN
# ...

# %%
data = pd.read_excel(link, header = None, index_col = 0)
data
# Out:
#                                                                                                   1   \
# 0
# PRÁCE A MZDY                                                                                     NaN
# 4 - 3.  Mezinárodní srovnání - Ekonomicky neakt...                                               NaN
#   International surveys - Economically inactive...                                               NaN
# NaN                                                                                              NaN
# Pramen / Source: Eurostat, 05/12/2016                                                            NaN
# NaN                                                                                              NaN
# Země                                                Studují či se jinak připravují na výkon povolání
# NaN                                                                         In education or training
# ...

# %%
data = pd.read_excel(link, header = None, index_col = 0, skiprows=6)
data
# Out:
#                                                                         1   \
# 0
# Země                      Studují či se jinak připravují na výkon povolání
# NaN                                               In education or training
# NaN                                                    15 - 24 let / years
# NaN                                                                   ženy
# NaN                                                                  Women
# EU 28                                                                  NaN
# Eurozóna 19                                                            NaN
# v tom:                                                                 NaN
# Belgie                                                                 NaN
# Bulharsko                                                              NaN
# Česká republika                                                        NaN
# ...

# %%
data = pd.read_excel(link, header = None, index_col = 0, skiprows=[0,1,2,3,4,5,7,10],)
data
# Out:
#                                                                         1   \
# 0
# Země                      Studují či se jinak připravují na výkon povolání
# NaN                                                    15 - 24 let / years
# NaN                                                                   ženy
# EU 28                                                                  NaN
# Eurozóna 19                                                            NaN
# v tom:                                                                 NaN
# Belgie                                                                 NaN
# Bulharsko                                                              NaN
# Česká republika                                                        NaN
# Dánsko                                                                 NaN
# Estonsko                                                               NaN
# ...

# %%
data = data.drop([17], axis=1)
data
# Out:
#                                                                         1   \
# 0
# Země                      Studují či se jinak připravují na výkon povolání
# NaN                                                    15 - 24 let / years
# NaN                                                                   ženy
# EU 28                                                                  NaN
# Eurozóna 19                                                            NaN
# v tom:                                                                 NaN
# Belgie                                                                 NaN
# Bulharsko                                                              NaN
# Česká republika                                                        NaN
# Dánsko                                                                 NaN
# Estonsko                                                               NaN
# ...

# %%
col1 = data.iloc[0].fillna(method = 'ffill')
col2 = data.iloc[1].str.split(pat='/', n = 0).str.get(0)
col3 = data.iloc[2].fillna(method = 'ffill')
columns = [col1, col2, col3]
columns = list(zip(*columns))

# %%
data.columns = columns
data
# Out:
#                          (Studují či se jinak připravují na výkon povolání, 15 - 24 let , ženy)  \
# 0
# Země                       Studují či se jinak připravují na výkon povolání
# NaN                                                     15 - 24 let / years
# NaN                                                                    ženy
# EU 28                                                                   NaN
# Eurozóna 19                                                             NaN
# v tom:                                                                  NaN
# Belgie                                                                  NaN
# Bulharsko                                                               NaN
# Česká republika                                                         NaN
# Dánsko                                                                  NaN
# Estonsko                                                                NaN
# ...

# %%
data.columns = pd.MultiIndex.from_tuples(data.columns)
data = data.drop(data.index[[0,1,2]])
data
# Out:
#                          Studují či se jinak připravují na výkon povolání  \
#                                                              15 - 24 let
#                                                                      ženy
# 0
# EU 28                                                                 NaN
# Eurozóna 19                                                           NaN
# v tom:                                                                NaN
# Belgie                                                                NaN
# Bulharsko                                                             NaN
# Česká republika                                                       NaN
# Dánsko                                                                NaN
# Estonsko                                                              NaN
# Finsko                                                                NaN
# Francie                                                               NaN
# ...
